# %% [markdown]
# # Datenvisualisierung mit matplotlib

# %%
from matplotlib import pyplot as plt
from pandas import read_csv
from numpy import mean, max, min, std
from seaborn import heatmap, clustermap, pairplot

# %% [markdown]
# ## Daten Laden

# %%
data = read_csv("data/diamonds.csv", sep=",")

# %%
data.head()
# Out:
#    id  carat      cut color clarity  depth  table  price     x     y     z
# 0   1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ## Visualisieren

# %%
pairplot(data)

# %%
heatmap(
    data.select_dtypes(include="number").corr()
)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8,8))
clustermap(data.select_dtypes(include="number").corr())
plt.savefig("clustermap.png")
plt.show()

# %% [markdown]
# ## Bokeh

# %%
from bokeh.plotting import figure, show, output_notebook, output_file

# %%
# output_file("mein_plot.html")

# %%
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f03b4743-cf78-471d-aac8-e2a262ca19e8">Loading BokehJS ...</span>
#     </div>

# %%
plot = figure(width=400, height=400)

plot.circle(data["depth"], data["table"])

show(plot)
# Out:
#   <div id="e2a739b0-ffc2-429e-8bd2-67abaf0292dc" data-root-id="p1001" style="display: contents;"></div>
